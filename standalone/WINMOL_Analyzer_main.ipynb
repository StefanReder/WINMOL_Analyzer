# %%
import os
import sys
import rasterio
import tensorflow as tf
from tensorflow import keras

import WINMOL_Analyzer as Analyzer
from WINMOL_Analyzer import Timer

from Config import Config

# Root directory of the project
ROOT_DIR = os.path.abspath(".//")

sys.path.append(ROOT_DIR)

# Directory whre the trained models are stored
model_dir = os.path.join(ROOT_DIR, "model//")

# Directory where the inpupt UAV-orthomosaics are stored
image_dir = os.path.join(ROOT_DIR, "input//")

# Directory to save the semantic stem map
pred_dir = os.path.join(ROOT_DIR, "pred//")

# Directory to save logs and trained model
output_dir = os.path.join(ROOT_DIR, "output//")

# %%
config = Config()
config.display()
# Out:
# Configurations:
# IMG_bit                        8
# IMG_height                     512
# IMG_width                      512
# max_distance                   8
# max_tree_height                32
# min_length                     2.0
# n_Channels                     3
# num_classes                    1
# overlapp_pred                  8
# tile_size                      15
# tolerance_angle                7

# %%
# Load your pre-trained U-Net model
model_path=os.path.join(model_dir, "UNet_SpecDS_UNet_Mask-RCNN_512_Spruce_2_model_2023-02-27_061925.hdf5")

# Load the model from the HDF5 file
model = keras.models.load_model(model_path, compile=False)

# Summary of the loaded model
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 512, 512, 3  0           []
#                                 )]
#
#  conv2d_1 (Conv2D)              (None, 512, 512, 64  1728        ['input_1[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 512, 512, 64  256        ['conv2d_1[0][0]']
#  rmalization)                   )
#
#  dropout (Dropout)              (None, 512, 512, 64  0           ['batch_normalization_1[0][0]']
#                                 )
#
#  conv2d (Conv2D)                (None, 512, 512, 64  36864       ['dropout[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 512, 512, 64  256        ['conv2d[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 256, 256, 64  0           ['batch_normalization[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 256, 256, 12  73728       ['max_pooling2d[0][0]']
#                                 8)
#
#  batch_normalization_3 (BatchNo  (None, 256, 256, 12  512        ['conv2d_3[0][0]']
#  rmalization)                   8)
#
#  dropout_1 (Dropout)            (None, 256, 256, 12  0           ['batch_normalization_3[0][0]']
#                                 8)
#
#  conv2d_2 (Conv2D)              (None, 256, 256, 12  147456      ['dropout_1[0][0]']
#                                 8)
#
#  batch_normalization_2 (BatchNo  (None, 256, 256, 12  512        ['conv2d_2[0][0]']
#  rmalization)                   8)
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 128, 128, 12  0          ['batch_normalization_2[0][0]']
#                                 8)
#
#  conv2d_5 (Conv2D)              (None, 128, 128, 25  294912      ['max_pooling2d_1[0][0]']
#                                 6)
#
#  batch_normalization_5 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_5[0][0]']
#  rmalization)                   6)
#
#  dropout_2 (Dropout)            (None, 128, 128, 25  0           ['batch_normalization_5[0][0]']
#                                 6)
#
#  conv2d_4 (Conv2D)              (None, 128, 128, 25  589824      ['dropout_2[0][0]']
#                                 6)
#
#  batch_normalization_4 (BatchNo  (None, 128, 128, 25  1024       ['conv2d_4[0][0]']
#  rmalization)                   6)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 64, 64, 256)  0          ['batch_normalization_4[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 64, 64, 512)  1179648     ['max_pooling2d_2[0][0]']
#
#  batch_normalization_7 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  dropout_3 (Dropout)            (None, 64, 64, 512)  0           ['batch_normalization_7[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 64, 64, 512)  2359296     ['dropout_3[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 64, 64, 512)  2048       ['conv2d_6[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 32, 32, 512)  0          ['batch_normalization_6[0][0]']
#
#  conv2d_9 (Conv2D)              (None, 32, 32, 1024  4718592     ['max_pooling2d_3[0][0]']
#                                 )
#
#  batch_normalization_9 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  dropout_4 (Dropout)            (None, 32, 32, 1024  0           ['batch_normalization_9[0][0]']
#                                 )
#
#  conv2d_8 (Conv2D)              (None, 32, 32, 1024  9437184     ['dropout_4[0][0]']
#                                 )
#
#  batch_normalization_8 (BatchNo  (None, 32, 32, 1024  4096       ['conv2d_8[0][0]']
#  rmalization)                   )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 64, 64, 512)  2097152    ['batch_normalization_8[0][0]']
#  spose)
#
#  batch_normalization_21 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_transpose_3[0][0]']
#  ormalization)
#
#  concatenate (Concatenate)      (None, 64, 64, 1024  0           ['batch_normalization_6[0][0]',
#                                 )                                 'batch_normalization_21[0][0]']
#
#  conv2d_18 (Conv2D)             (None, 64, 64, 512)  4718592     ['concatenate[0][0]']
#
#  batch_normalization_20 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_18[0][0]']
#  ormalization)
#
#  dropout_8 (Dropout)            (None, 64, 64, 512)  0           ['batch_normalization_20[0][0]']
#
#  conv2d_17 (Conv2D)             (None, 64, 64, 512)  2359296     ['dropout_8[0][0]']
#
#  batch_normalization_19 (BatchN  (None, 64, 64, 512)  2048       ['conv2d_17[0][0]']
#  ormalization)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 128, 128, 25  524288     ['batch_normalization_19[0][0]']
#  spose)                         6)
#
#  batch_normalization_18 (BatchN  (None, 128, 128, 25  1024       ['conv2d_transpose_2[0][0]']
#  ormalization)                  6)
#
#  concatenate_1 (Concatenate)    (None, 128, 128, 51  0           ['batch_normalization_4[0][0]',
#                                 2)                                'batch_normalization_18[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 128, 128, 26  1221120     ['concatenate_1[0][0]']
#                                 5)
#
#  batch_normalization_17 (BatchN  (None, 128, 128, 26  1060       ['conv2d_16[0][0]']
#  ormalization)                  5)
#
#  dropout_7 (Dropout)            (None, 128, 128, 26  0           ['batch_normalization_17[0][0]']
#                                 5)
#
#  conv2d_15 (Conv2D)             (None, 128, 128, 26  632025      ['dropout_7[0][0]']
#                                 5)
#
#  batch_normalization_16 (BatchN  (None, 128, 128, 26  1060       ['conv2d_15[0][0]']
#  ormalization)                  5)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 256, 256, 12  135680     ['batch_normalization_16[0][0]']
#  spose)                         8)
#
#  batch_normalization_15 (BatchN  (None, 256, 256, 12  512        ['conv2d_transpose_1[0][0]']
#  ormalization)                  8)
#
#  concatenate_2 (Concatenate)    (None, 256, 256, 25  0           ['batch_normalization_2[0][0]',
#                                 6)                                'batch_normalization_15[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 256, 256, 12  294912      ['concatenate_2[0][0]']
#                                 8)
#
#  batch_normalization_14 (BatchN  (None, 256, 256, 12  512        ['conv2d_14[0][0]']
#  ormalization)                  8)
#
#  dropout_6 (Dropout)            (None, 256, 256, 12  0           ['batch_normalization_14[0][0]']
#                                 8)
#
#  conv2d_13 (Conv2D)             (None, 256, 256, 12  147456      ['dropout_6[0][0]']
#                                 8)
#
#  batch_normalization_13 (BatchN  (None, 256, 256, 12  512        ['conv2d_13[0][0]']
#  ormalization)                  8)
#
#  conv2d_transpose (Conv2DTransp  (None, 512, 512, 64  32768      ['batch_normalization_13[0][0]']
#  ose)                           )
#
#  batch_normalization_12 (BatchN  (None, 512, 512, 64  256        ['conv2d_transpose[0][0]']
#  ormalization)                  )
#
#  concatenate_3 (Concatenate)    (None, 512, 512, 12  0           ['batch_normalization[0][0]',
#                                 8)                                'batch_normalization_12[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 512, 512, 64  73728       ['concatenate_3[0][0]']
#                                 )
#
#  batch_normalization_11 (BatchN  (None, 512, 512, 64  256        ['conv2d_12[0][0]']
#  ormalization)                  )
#
#  dropout_5 (Dropout)            (None, 512, 512, 64  0           ['batch_normalization_11[0][0]']
#                                 )
#
#  conv2d_11 (Conv2D)             (None, 512, 512, 64  36864       ['dropout_5[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 512, 512, 64  256        ['conv2d_11[0][0]']
#  ormalization)                  )
#
#  conv2d_10 (Conv2D)             (None, 512, 512, 1)  65          ['batch_normalization_10[0][0]']
#
# ==================================================================================================
# Total params: 31,140,642
# Trainable params: 31,126,910
# Non-trainable params: 13,732
# __________________________________________________________________________________________________

# %%
img_list=os.listdir(image_dir)
img_list= [i for i in img_list if i.endswith((".tiff",".tif")) ]
img_name=img_list[0]
print(img_name)
file_name = os.path.splitext(os.path.basename(img_name))[0]
# Out:
# 20220209_Bremerhagen_2.tiff

# %%
#Predict with resampling per tile

tt = Timer()
tt.start()

img, profile =Analyzer.IO.load_orthomosaic(image_dir+img_name, config)
 
pred, profile=Analyzer.Pred.predict_with_resampling_per_tile(img, profile, model,config)     
segments = Analyzer.Skel.find_segments(pred, config, profile)
segments = Analyzer.Vec.restore_geoinformation(segments, config, profile)
stems = Analyzer.Vec.build_stem_parts(segments)
stems = Analyzer.Vec.connect_stems(stems,config)  
endnodes = Analyzer.Vec.rebuild_endnodes_from_stems(stems)   
stems = Analyzer.Quant.quantify_stems(stems, pred, profile, pred_dir+'pred_'+file_name+'.tiff')

Analyzer.IO.export_stem_map(pred, profile, pred_dir, file_name)   
Analyzer.IO.stems_to_geojson(stems, output_dir+file_name)

tt.stop()
# Out:
# #######################################################
# Prediction of the semantic stem map
# Resampling tiles while analyzing
# 24  tiles analyzed
# Elapsed time: 4.9867 seconds
# #######################################################
#
# #######################################################
# Skeletonize Image
# Elapsed time: 0.5692 seconds
# #######################################################
#
# #######################################################
# Splitting the skeleton into segments and detecting endnodes
# Dense nodes removed:  12
# Brachpoints removed:  261
# Detected endnodes:  454
# Elapsed time: 8.1353 seconds
# #######################################################
#
# #######################################################
# Find connected segments in the skeleton
# Initial length of skeleton:  9921
# Number of endnodes 454
# Minimum length in pixel:  17
# Detected skeleton segments:  93
# Elapsed time: 16.2364 seconds
# #######################################################
#
# #######################################################
# #Refining and sorting out skeleton segments
# Initial length of skeleton:  9165
# Number of initial skeleton segments 93
# Number of split segments: 46
# Number of removed segments: 38
# Number of refined segments: 101
# Elapsed time: 8.9316 seconds
# #######################################################
#
# #######################################################
# Restoring geoinformation
# Elapsed time: 0.0006 seconds
# #######################################################
#
# #######################################################
# Build stem segments
# 101 stems segments build
# Elapsed time: 0.0029 seconds
# #######################################################
#
# #######################################################
# Gethering stem segments
# Cycle  1
# Cycle  2
#
# 101 stem segments analyzed
# 42 stem segments appended to other stems
# 48 duplicates are removed
# 22 stem fragments with a length less than  2.0 m are filtered out
# final number of stems 31
# Elapsed time: 16.1937 seconds
# #######################################################
#
# #######################################################
# Rebuild endnodes from stems
# Elapsed time: 0.0009 seconds
# #######################################################
#
# #######################################################
# Quantifying stems
# 508  measurements of diameters where conducted
# Volume of  31  stems calculated
# Elapsed time: 18.9003 seconds
# #######################################################
#
# #######################################################
# Export to GeoJSON
# Wrote P:\WINMOL_Analyzer\output//20220209_Bremerhagen_2_stems.geojson
# Wrote P:\WINMOL_Analyzer\output//20220209_Bremerhagen_2_nodes.geojson
# Wrote P:\WINMOL_Analyzer\output//20220209_Bremerhagen_2_vectors.geojson
# #######################################################
#
# Elapsed time: 75.0960 seconds
